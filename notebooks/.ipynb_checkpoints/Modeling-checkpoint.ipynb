# %% [markdown]
# # Outline:
# 1. Exploratory data analysis
# 3. Modeling
# 4. Conclusion

# %% [markdown]
# ## Exploratory data analysis
# In this notebook, we will explore the data collected for the Indonesian sign language recognition project. Let's explore the datasets first and then we will move into the modeling stage. The datasets contains action videos recorded in MP4 format for different words.

# %%
# import all the packages
import os
import glob
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
# This file path contains all the preprocessed data ready for CNN-based models having fixed frames and resolutions.
data_path = "../data/preprocessed/"

# List the contents of the file path
# !ls ../data/preprocessed/
# Out:
# adik     buruk    haus     kertas   maaf     minum    rumah    teman
# anak     dengar   ibu      kucing   main     nama     sedikit  tidur
# besar    gembira  jalan    lapar    makan    orang    selamat
# buka     guru     keluarga lihat    marah    panggil  senyum

# %% [markdown]
# The names of the each folder corresponds to an Indonesian word and it contains the corresponding action videos. Let's check the contents of the "adik" folder.

# %%
# !ls ../data/preprocessed/adik
# Out:
# 1_normalized.mp4                kenji_normalized.mp4
# Bhavitha_Bojja_normalized.mp4   kenzo_7_normalized.mp4
# Monu_Babu_Baitha_normalized.mp4 louis_9_normalized.mp4
# Roshan_Thapa_normalized.mp4     mahsa_normalized.mp4
# Viorelia_normalized.mp4         vaishnavi_desai_normalized.mp4

# %% [markdown]
# The first folder contains the normalized version of the action videos recorded by multiple people and it contains 10 videos. These videos were recorded by multiple collaborators who are part of this Omdena challenge,
#
# Let's take a look at the other folders as well.

# %%
# Listing number of video files in each folder list
folds = os.listdir(data_path)
file_list = np.zeros(len(folds))

# Collecting the filepath of each video files and their associated folder labeling
# Will be used for train and test split of the data
video_filepath = []
labels = []

for i,fold in enumerate(sorted(folds)):
    files = glob.glob(data_path+fold+"/*.mp4")
    nfiles = len(files)
    file_list[i] = nfiles
    for filepath in files:
        video_filepath.append(filepath)
        labels.append(i)

# saving the information into a pandas dictionary
df = pd.DataFrame.from_dict({'X_path':video_filepath, 'Y':labels})
df = df.sample(frac=1) # shuffling the data

fig, ax = plt.subplots(figsize=(14,8))

ax.bar(sorted(folds), file_list)
ax.set_ylabel("No. of files")
ax.tick_params(axis='x', labelrotation = 45)
plt.show()

# %% [markdown]
# Here each of the xlabels represent an Indonesian word and the video files associated with that.
# Now let's take a look at the frame rates and resolution of videos in these folders.

# %%
filename = data_path+"/adik/1_normalized.mp4"
ipd.Video(filename, width=800)
# Out:
# <video src="../data/preprocessed//adik/1_normalized.mp4" controls  width="800" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# Let's iterate through each folder and the files to collect some metadata
folds = os.listdir(data_path)

for fold in sorted(folds):
    files = glob.glob(data_path+fold+"/*.mp4")
    for file in files:
        # Load the video
        vid = cv2.VideoCapture(file)
        
        # Get the framerate
        fr = vid.get(cv2.CAP_PROP_FPS)

        # Total number of frames
        nframes = vid.get(cv2.CAP_PROP_FRAME_COUNT)

        # Duration
        dur = nframes/fr
        
        # Video height and width
        height = vid.get(cv2.CAP_PROP_FRAME_HEIGHT)
        width = vid.get(cv2.CAP_PROP_FRAME_WIDTH)
        
        print(f"{fold}, {os.path.basename(file)}, Frame rate: {fr}, No. of Frames : {nframes}, Duration:{dur}s, Height {height}, Width {width}")

        # Unload the video
        vid.release()
# Out:
# adik, Viorelia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# adik, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# adik, vaishnavi_desai_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# adik, Roshan_Thapa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# adik, louis_9_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# adik, Bhavitha_Bojja_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# adik, kenzo_7_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# adik, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# adik, Monu_Babu_Baitha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# adik, mahsa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# anak, Viorelia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# anak, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# anak, vaishnavi_desai_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# anak, Roshan_Thapa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# anak, louis_1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# anak, Bhavitha_Bojja_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# anak, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# anak, Monu_Babu_Baitha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# anak, mahsa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# anak, kenzo_3_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# besar, Viorelia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# besar, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# besar, vaishnavi_desai_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# besar, Roshan_Thapa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# besar, kenzo_1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# besar, Bhavitha_Bojja_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# besar, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# besar, louis_2_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# besar, Monu_Babu_Baitha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# besar, mahsa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buka, Viorelia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buka, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buka, vaishnavi_desai_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buka, Roshan_Thapa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buka, Bhavitha_Bojja_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buka, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buka, Monu_Babu_Baitha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buka, kenzo_4_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buka, mahsa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buka, louis_3_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buruk, Viorelia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buruk, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buruk, vaishnavi_desai_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buruk, Roshan_Thapa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buruk, Bhavitha_Bojja_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buruk, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buruk, kenzo_2_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buruk, Monu_Babu_Baitha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buruk, mahsa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# buruk, louis_4_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# dengar, Viorelia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# dengar, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# dengar, vaishnavi_desai_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# dengar, Roshan_Thapa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# dengar, Bhavitha_Bojja_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# dengar, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# dengar, louis_5_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# dengar, kenzo_5_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# dengar, Monu_Babu_Baitha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# dengar, mahsa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# gembira, Viorelia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# gembira, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# gembira, vaishnavi_desai_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# gembira, Roshan_Thapa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# gembira, louis_7_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# gembira, Bhavitha_Bojja_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# gembira, kenzo_8_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# gembira, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# gembira, Monu_Babu_Baitha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# gembira, mahsa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# guru, viorelia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# guru, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# guru, vaishnavi_desai_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# guru, Roshan_Thapa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# guru, kenzo_6_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# guru, Bhavitha_Bojja_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# guru, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# guru, louis_8_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# guru, Monu_Babu_Baitha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# guru, mahsa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# haus, Viorelia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# haus, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# haus, vaishnavi_desai_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# haus, Roshan_Thapa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# haus, louis_9_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# haus, kenzo_9_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# haus, Bhavitha_Bojja_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# haus, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# haus, Monu_Babu_Baitha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# haus, mahsa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# ibu, Viorelia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# ibu, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# ibu, kenzo_10_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# ibu, vaishnavi_desai_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# ibu, Roshan_Thapa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# ibu, louis_10_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# ibu, Bhavitha_Bojja_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# ibu, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# ibu, Monu_Babu_Baitha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# ibu, mahsa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# jalan, dina_jalan_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# jalan, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# jalan, shikha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# jalan, Arun_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# jalan, Deepa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# jalan, Anastasiia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# jalan, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# jalan, nadya_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# keluarga, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# keluarga, shikha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# keluarga, Arun_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# keluarga, dina_keluarga_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# keluarga, Deepa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# keluarga, Anastasiia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# keluarga, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# keluarga, nadya_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kertas, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kertas, shikha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kertas, Arun_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kertas, Deepa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kertas, Anastasiia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kertas, dina_kertas_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kertas, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kertas, nadya_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kucing, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kucing, shikha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kucing, Arun_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kucing, Deepa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kucing, Anastasiia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kucing, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kucing, nadya_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# kucing, dina_kucing_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lapar, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lapar, shikha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lapar, Arun_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lapar, dina_lapar_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lapar, Deepa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lapar, Anastasiia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lapar, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lapar, nadya_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lihat, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lihat, shikha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lihat, Arun_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lihat, dina_lihat_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lihat, Deepa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lihat, Anastasiia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lihat, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# lihat, nadya_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# maaf, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# maaf, shikha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# maaf, Arun_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# maaf, Deepa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# maaf, Anastasiia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# maaf, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# maaf, nadya_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# maaf, dina_maaf_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# main, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# main, shikha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# main, Arun_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# main, Deepa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# main, Anastasiia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# main, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# main, nadya_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# main, dina_main_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# makan, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# makan, shikha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# makan, Arun_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# makan, dina_makan_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# makan, Deepa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# makan, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# makan, nadya_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# marah, Rebecca P_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# marah, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# marah, Marouf_marah_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# marah, kenzo_13_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# marah, marah_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# marah, louis_0_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# marah, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# marah, thant htoo san_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# marah, dina_marah_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# minum, louis_12_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# minum, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# minum, kenzo_12_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# minum, Marouf_minum_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# minum, Rebecca_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# minum, minum_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# minum, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# minum, thant htoo san_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# nama, kenzo_11_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# nama, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# nama, Marouf_nama_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# nama, Rebecca_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# nama, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# nama, thant htoo san_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# nama, louis_2_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# nama, nama_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# orang, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# orang, kenzo_14_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# orang, orang_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# orang, Rebecca_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# orang, Marouf_orang_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# orang, thant htoo san_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# orang, louis_3_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# panggil, panggil_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# panggil, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# panggil, kenzo_15_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# panggil, Rebecca_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# panggil, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# panggil, thant htoo san_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# panggil, Marouf_panggil_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# panggil, louis_4_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# rumah, kenzo_16_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# rumah, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# rumah, rumah_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# rumah, Rebecca_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# rumah, Marouf_rumah_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# rumah, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# rumah, thant htoo san_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# rumah, louis_5_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# sedikit, kenzo_17_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# sedikit, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# sedikit, Marouf_Sedikit_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# sedikit, Rebecca_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# sedikit, louis_6_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# sedikit, sedikit_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# sedikit, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# sedikit, thant htoo san_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# selamat, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# selamat, kenzo_18_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# selamat, Marouf_selemat_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# selamat, thant_htoo_san_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# selamat, Rebecca_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# selamat, louis_7_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# selamat, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# selamat, selamat_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# senyum, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# senyum, Marouf_senyum_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# senyum, Rebecca_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# senyum, kenzo_20_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# senyum, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# senyum, senyum_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# senyum, louis_8_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# senyum, thant htoo san_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# teman, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# teman, shikha_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# teman, Arun_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# teman, Deepa_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# teman, Anastasiia_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# teman, kenji_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# teman, nadya_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# tidur, kenzo_19_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# tidur, 1_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# tidur, tidur_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# tidur, Rebecca_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# tidur, louis_6_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# tidur, Marouf_tidur_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0
# tidur, thant htoo san (2)_normalized.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 224.0, Width 224.0

# %% [markdown]
# These are preprocessed videos and all of them have the same number of frames, frame rate, duration and image dimensions.

# %%
# Let's take a look at different frames in a single video from the first folder
images = []
for fold in sorted(folds)[:1]:
    files = glob.glob(data_path+fold+"/*.mp4")
    for file in files[:1]:
        # Load the video
        vid = cv2.VideoCapture(file)
        
        # Get the framerate
        fr = vid.get(cv2.CAP_PROP_FPS)

        # Total number of frames
        nframes = vid.get(cv2.CAP_PROP_FRAME_COUNT)

        while True:
            ret, img = vid.read()
            if ret == False:
                break
            else:
                images.append(img)

        # Unload the video
        vid.release()


fig, axs = plt.subplots(4, 4, figsize=(12,10), tight_layout = True)
axs = axs.flatten()
for i in range(len(axs)):
    axs[i].imshow(images[i])
    axs[i].set_title(f"frame:{i}")
    axs[i].axis("off")
plt.show()

# %% [markdown]
# ## Data Preprocessing
# Here we will do a test-train split of the data first. We will try out the model first and then move on the data augmentation part. For that we need to collect the filepath of each video file and the associated labeling with it. There are in total 30 output classes which can be labelled from 0 to 29.
#
# ### Data Splitting

# %%
# data frame containing list of files and labels
df.head(10)
# Out:
#                                                 X_path   Y
# 245     ../data/preprocessed/teman/Arun_normalized.mp4  28
# 24   ../data/preprocessed/besar/kenzo_1_normalized.mp4   2
# 144    ../data/preprocessed/lihat/Deepa_normalized.mp4  15
# 83   ../data/preprocessed/haus/Roshan_Thapa_normali...   8
# 74    ../data/preprocessed/guru/kenzo_6_normalized.mp4   7
# 88   ../data/preprocessed/haus/Monu_Babu_Baitha_nor...   8
# 107    ../data/preprocessed/jalan/nadya_normalized.mp4  10
# 87      ../data/preprocessed/haus/kenji_normalized.mp4   8
# 110  ../data/preprocessed/keluarga/Arun_normalized.mp4  11
# 30   ../data/preprocessed/buka/Viorelia_normalized.mp4   3

# %%
from sklearn.model_selection import train_test_split

# stratisfied splitting the data into 70% train and 30 % test to ensure that the test data contains 
# more or less equal distributions of different classes
X_train_path, X_test_path, Y_train, Y_test = train_test_split(df['X_path'], df['Y'], test_size=0.3, random_state=42, stratify = df['Y'])

# checking the number of samples in each category of the test data
Y_test.value_counts().sort_values()
#X_train_path.head(5)
# Out:
# Y
# 21    2
# 22    2
# 15    2
# 16    2
# 11    2
# 25    2
# 18    2
# 28    2
# 24    2
# 20    2
# 10    2
# 29    2
# 5     3
# 23    3
# 3     3
# 1     3
# 4     3
# 7     3
# 13    3
# 14    3
# 19    3
# 26    3
# 0     3
# 17    3
# 6     3
# 8     3
# 9     3
# 27    3
# 12    3
# 2     3
# Name: count, dtype: int64

# %% [markdown]
# ### Data extraction from the video files

# %%
def load_data(df):
    """
    Returns the array with loaded images from
    videos
    args:
    df : dataframe containing the filepaths
    """
    samp = df.shape[0]
    #print(samp)
    data = np.zeros((samp, 30, 224, 224, 3), dtype = np.float32) # Each video has 30 frames and each frame has 224 pixels height, width and 3 channels
    for i in range(samp):
        filename = df.iloc[i]
        
        # Load the video
        vid = cv2.VideoCapture(filename)
        
        # Total number of frames
        nframes = int(vid.get(cv2.CAP_PROP_FRAME_COUNT))

        for f in range(nframes):
            
            ret, img = vid.read()
            if ret == False:
                break
            else:
                data[i,f,:,:,:] = img/255

        # Unload the video
        vid.release()

    return data

# %%
# Get the train data and test data

X_train = load_data(X_train_path)
X_test = load_data(X_test_path)

print(f" X train shape : {X_train.shape}")
print(f"X test shape : {X_test.shape}")
# Out:
#  X train shape : (179, 30, 224, 224, 3)
# X test shape : (78, 30, 224, 224, 3)

# %%
# Let's plot a random video file (eg: 30 th file) and check the data frames
fig, axs = plt.subplots(4, 4, figsize=(12,10), tight_layout = True)
axs = axs.flatten()
for i in range(len(axs)):
    axs[i].imshow(X_train[30, i, :, :, :])
    axs[i].set_title(f"frame:{i}")
    axs[i].axis("off")
plt.show()

# %% [markdown]
# ## Modeling of the data
# We will start with a simple CNN-LSTM model and see how it performs. Depending on the metrics, we can carry out video augmentation and other models. Let's build the model using keras and tensorflow.
#
# In the case of a CNN-LSTM model, the CNN will extract the features from each frame of the image and they are fed to the LSTM model for modeling the temporal variations in the video. The **TimeDistributed** wrapper in Keras can be used to apply the same convolutionsl operations to different time frames and combine the results after that. Let's build the model now.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D, Dropout, Input, TimeDistributed, LSTM

def create_CNN_LSTM(input_shape, nclass):

    """
    Function returns the model output
    Args:
    input shape: shape of the input train/test data (excluding the batch size)
    nclass: number of output classes
    """
    model = Sequential()

    # CNN part
    model.add(Input(shape=input_shape))
    model.add(TimeDistributed(Conv2D(filters=32, kernel_size=3, strides=(1,1), activation='relu', padding='valid', name = 'conv1')))
    model.add(TimeDistributed(MaxPool2D(pool_size=(4, 4), strides=(2,2), name = 'pool1')))
    model.add(TimeDistributed(Conv2D(filters=64, kernel_size=3, strides=(1,1), activation='relu', padding='valid', name = 'conv2')))
    model.add(TimeDistributed(MaxPool2D(pool_size=(4, 4), strides=(4,4), name = 'pool2')))
    model.add(TimeDistributed(Conv2D(filters=128, kernel_size=3, strides=(1,1), activation='relu', padding='valid', name = 'conv3')))
    model.add(TimeDistributed(MaxPool2D(pool_size=(4, 4), strides=(4,4), name = 'pool3')))
    model.add(TimeDistributed(Flatten()))
              
    # LSTM part
    model.add(LSTM(64))
              
    # Drop out regularization
    model.add(Dropout(0.2))
              
    # fully connected layers
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))

    # Final output layer, softmax regression
    model.add(Dense(nclass, activation='softmax'))

    model.summary()

    return model

# %%
nclass = len(np.unique(Y_train))
input_shape = X_train.shape[1:] 

print(f"Number of classes : {nclass}")
cnn_lstm = create_CNN_LSTM(input_shape, nclass)
# Out:
# Number of classes : 30
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_21 (TimeDi  (None, 30, 222, 222, 32)  896
#  stributed)
#
#  time_distributed_22 (TimeDi  (None, 30, 110, 110, 32)  0
#  stributed)
#
#  time_distributed_23 (TimeDi  (None, 30, 108, 108, 64)  18496
#  stributed)
#
#  time_distributed_24 (TimeDi  (None, 30, 27, 27, 64)   0
#  stributed)
#
#  time_distributed_25 (TimeDi  (None, 30, 25, 25, 128)  73856
#  stributed)
#
#  time_distributed_26 (TimeDi  (None, 30, 6, 6, 128)    0
#  stributed)
#
#  time_distributed_27 (TimeDi  (None, 30, 4608)         0
#  stributed)
#
#  lstm_3 (LSTM)               (None, 64)                1196288
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 128)               8320
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dense_11 (Dense)            (None, 30)                1950
#
# =================================================================
# Total params: 1,308,062
# Trainable params: 1,308,062
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile and train the model
cnn_lstm.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
# If the y labels are intigers use sparse categorical entropy loss function, if y labels are one hot encoded then utilize the categorical
# cross entropy

# let's set the test data as the validation data as of now since we have limited data for training.
hist_cnn_lstm = cnn_lstm.fit(X_train, Y_train, epochs=10, batch_size=32, validation_data = (X_test, Y_test))
# Out:
# Epoch 1/10
# 6/6 [==============================] - 193s 31s/step - loss: 3.4020 - accuracy: 0.0447 - val_loss: 3.4099 - val_accuracy: 0.0385
# Epoch 2/10
# 6/6 [==============================] - 184s 31s/step - loss: 3.4129 - accuracy: 0.0279 - val_loss: 3.4079 - val_accuracy: 0.0385
# Epoch 3/10
# 6/6 [==============================] - 11012s 1089s/step - loss: 3.3897 - accuracy: 0.0670 - val_loss: 3.4032 - val_accuracy: 0.0256
# Epoch 4/10
# 6/6 [==============================] - 191s 32s/step - loss: 3.3871 - accuracy: 0.0559 - val_loss: 3.4024 - val_accuracy: 0.0256
# Epoch 5/10
# 6/6 [==============================] - 193s 32s/step - loss: 3.3886 - accuracy: 0.0670 - val_loss: 3.4052 - val_accuracy: 0.0128
# Epoch 6/10
# 6/6 [==============================] - 2313s 456s/step - loss: 3.3748 - accuracy: 0.0615 - val_loss: 3.4043 - val_accuracy: 0.0256
# Epoch 7/10
# 6/6 [==============================] - 14431s 34s/step - loss: 3.3559 - accuracy: 0.0503 - val_loss: 3.4153 - val_accuracy: 0.0513
# Epoch 8/10
# 6/6 [==============================] - 188s 31s/step - loss: 3.3381 - accuracy: 0.0447 - val_loss: 3.4281 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 6/6 [==============================] - 183s 30s/step - loss: 3.2974 - accuracy: 0.0950 - val_loss: 3.4318 - val_accuracy: 0.0256
# Epoch 10/10
# 6/6 [==============================] - 178s 30s/step - loss: 3.2813 - accuracy: 0.1006 - val_loss: 3.4406 - val_accuracy: 0.0256

# %%
# The history.history["loss"] entry is a dictionary with as many values as epochs that the
# model was trained on. 
df_loss_acc = pd.DataFrame(hist_cnn_lstm.history)

# losses data frame
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)

# accuracy data frame
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)

# plotting the loss and accuracy
df_loss.plot(title='Model loss',figsize=(8,6)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(8,6)).set(xlabel='Epoch',ylabel='Accuracy')
# Out:
# /var/folders/c8/g5hp4hlx7dv6gv7n9zdg74rc0000gn/T/ipykernel_57749/3660938882.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
# /var/folders/c8/g5hp4hlx7dv6gv7n9zdg74rc0000gn/T/ipykernel_57749/3660938882.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Accuracy')]

# %% [markdown]
# ## Conclusion
#
# The simple CNN-LSTM model is not learning well as we can see from the training history. The issues causing this needs to be figured out.
