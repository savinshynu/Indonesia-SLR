# %% [markdown]
# # Outline:
# 1. Exploratory data analysis
# 3. Modeling
# 4. Conclusion

# %% [markdown]
# ## Exploratory data analysis
# In this notebook, we will explore the data collected for the Indonesian sign language recognition project. Let's explore the datasets first and then we will move into the modeling stage. The datasets contains action videos recorded in MP4 format for different words.

# %%
# import all the packages
import os
import glob
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
# This file path contains all the preprocessed data ready for CNN-based models having fixed frames and resolutions.
data_path = "../data/data_processed_v1/"

# List the contents of the file path
# !ls ../data/data_processed_v1/
# Out:
# adik     buruk    haus     kertas   maaf     minum    rumah    teman
# anak     dengar   ibu      kucing   main     nama     sedikit  tidur
# besar    gembira  jalan    lapar    makan    orang    selamat
# buka     guru     keluarga lihat    marah    panggil  senyum

# %% [markdown]
# The names of the each folder corresponds to an Indonesian word and it contains the corresponding action videos. Let's check the contents of the "adik" folder.

# %%
# !ls ../data/preprocessed/adik
# Out:
# 1_normalized.mp4                kenji_normalized.mp4
# Bhavitha_Bojja_normalized.mp4   kenzo_7_normalized.mp4
# Monu_Babu_Baitha_normalized.mp4 louis_9_normalized.mp4
# Roshan_Thapa_normalized.mp4     mahsa_normalized.mp4
# Viorelia_normalized.mp4         vaishnavi_desai_normalized.mp4

# %% [markdown]
# The first folder contains the normalized version of the action videos recorded by multiple people and it contains 10 videos. These videos were recorded by multiple collaborators who are part of this Omdena challenge,
#
# Let's take a look at the other folders as well.

# %%
# Listing number of video files in each folder list
folds = os.listdir(data_path)
file_list = np.zeros(len(folds))

# Collecting the filepath of each video files and their associated folder labeling
# Will be used for train and test split of the data
video_filepath = []
labels = []

for i,fold in enumerate(sorted(folds)):
    files = glob.glob(data_path+fold+"/*.mp4")
    nfiles = len(files)
    file_list[i] = nfiles
    for filepath in files:
        video_filepath.append(filepath)
        labels.append(i)

# saving the information into a pandas dictionary
df = pd.DataFrame.from_dict({'X_path':video_filepath, 'Y':labels})
df = df.sample(frac=1) # shuffling the data

fig, ax = plt.subplots(figsize=(14,8))

ax.bar(sorted(folds), file_list)
ax.set_ylabel("No. of files")
ax.tick_params(axis='x', labelrotation = 45)
plt.show()

# %% [markdown]
# Here each of the xlabels represent an Indonesian word and the video files associated with that.
# Now let's take a look at the frame rates and resolution of videos in these folders.

# %%
filename = data_path+"/adik/1_normalized.mp4"
ipd.Video(filename)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 filename = data_path+"/adik/1_normalized.mp4"
# ----> 2 ipd.Video(filename)
#
# File ~/opt/anaconda3/envs/ds/lib/python3.9/site-packages/IPython/core/display.py:1162, in Video.__init__(self, data, url, filename, embed, mimetype, width, height, html_attributes)
#    1156 if data and not embed:
#    1157     msg = ''.join([
#    1158         "To embed videos, you must pass embed=True ",
#    1159         "(this may make your notebook files huge)\n",
#    1160         "Consider passing Video(url='...')",
#    1161     ])
# -> 1162     raise ValueError(msg)
#    1164 self.mimetype = mimetype
#    1165 self.embed = embed
#
# ValueError: To embed videos, you must pass embed=True (this may make your notebook files huge)
# Consider passing Video(url='...')

# %%
# Let's iterate through each folder and the files to collect some metadata
folds = os.listdir(data_path)

for fold in sorted(folds):
    files = glob.glob(data_path+fold+"/*.mp4")
    for file in files:
        # Load the video
        vid = cv2.VideoCapture(file)
        
        # Get the framerate
        fr = vid.get(cv2.CAP_PROP_FPS)

        # Total number of frames
        nframes = vid.get(cv2.CAP_PROP_FRAME_COUNT)

        # Duration
        dur = nframes/fr
        
        # Video height and width
        height = vid.get(cv2.CAP_PROP_FRAME_HEIGHT)
        width = vid.get(cv2.CAP_PROP_FRAME_WIDTH)
        
        print(f"{fold}, {os.path.basename(file)}, Frame rate: {fr}, No. of Frames : {nframes}, Duration:{dur}s, Height {height}, Width {width}")

        # Unload the video
        vid.release()
# Out:
# adik, Viorelia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# adik, kenzo_7_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# adik, Bhavitha_Bojja_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# adik, Monu_Babu_Baitha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# adik, vaishnavi_desai_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# adik, louis_9_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# adik, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# adik, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# adik, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# adik, Roshan_Thapa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# anak, Viorelia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# anak, kenzo_3_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# anak, Bhavitha_Bojja_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# anak, Monu_Babu_Baitha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# anak, vaishnavi_desai_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# anak, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# anak, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# anak, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# anak, Roshan_Thapa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# anak, louis_1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# besar, Viorelia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# besar, Bhavitha_Bojja_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# besar, Monu_Babu_Baitha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# besar, vaishnavi_desai_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# besar, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# besar, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# besar, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# besar, Roshan_Thapa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# besar, louis_2_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# besar, kenzo_1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buka, kenzo_4_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buka, Viorelia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buka, louis_3_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buka, Bhavitha_Bojja_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buka, Monu_Babu_Baitha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buka, vaishnavi_desai_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buka, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buka, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buka, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buka, Roshan_Thapa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buruk, Viorelia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buruk, louis_4_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buruk, Bhavitha_Bojja_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buruk, Monu_Babu_Baitha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buruk, vaishnavi_desai_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buruk, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buruk, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buruk, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buruk, Roshan_Thapa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# buruk, kenzo_2_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# dengar, Viorelia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# dengar, Bhavitha_Bojja_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# dengar, Monu_Babu_Baitha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# dengar, vaishnavi_desai_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# dengar, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# dengar, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# dengar, mahsa_flipped_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# dengar, Roshan_Thapa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# dengar, kenzo_5_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# dengar, louis_5_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# gembira, Viorelia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# gembira, louis_7_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# gembira, Bhavitha_Bojja_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# gembira, Monu_Babu_Baitha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# gembira, vaishnavi_desai_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# gembira, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# gembira, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# gembira, kenzo_8_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# gembira, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# gembira, Roshan_Thapa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# guru, viorelia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# guru, Bhavitha_Bojja_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# guru, Monu_Babu_Baitha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# guru, vaishnavi_desai_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# guru, Roshan_Thapa_flipped_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# guru, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# guru, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# guru, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# guru, louis_8_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# guru, kenzo_6_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# haus, Viorelia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# haus, Bhavitha_Bojja_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# haus, Monu_Babu_Baitha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# haus, vaishnavi_desai_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# haus, kenzo_9_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# haus, louis_9_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# haus, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# haus, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# haus, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# haus, Roshan_Thapa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# ibu, Viorelia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# ibu, louis_10_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# ibu, kenzo_10_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# ibu, Bhavitha_Bojja_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# ibu, Monu_Babu_Baitha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# ibu, vaishnavi_desai_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# ibu, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# ibu, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# ibu, mahsa_flipped_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# ibu, Roshan_Thapa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# jalan, Deepa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# jalan, Anastasiia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# jalan, dina_jalan_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# jalan, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# jalan, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# jalan, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# jalan, Ellen_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# jalan, shikha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# jalan, Arun_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# jalan, nadya_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# keluarga, Deepa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# keluarga, Anastasiia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# keluarga, dina_keluarga_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# keluarga, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# keluarga, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# keluarga, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# keluarga, Ellen_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# keluarga, shikha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# keluarga, Arun_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# keluarga, nadya_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kertas, Deepa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kertas, Anastasiia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kertas, dina_kertas_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kertas, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kertas, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kertas, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kertas, Ellen_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kertas, shikha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kertas, Arun_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kertas, nadya_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kucing, Deepa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kucing, Anastasiia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kucing, dina_kucing_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kucing, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kucing, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kucing, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kucing, Ellen_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kucing, shikha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kucing, Arun_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# kucing, nadya_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lapar, Deepa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lapar, Anastasiia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lapar, dina_lapar_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lapar, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lapar, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lapar, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lapar, Ellen_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lapar, shikha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lapar, Arun_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lapar, nadya_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lihat, Deepa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lihat, Anastasiia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lihat, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lihat, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lihat, dina_lihat_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lihat, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lihat, Ellen_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lihat, shikha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lihat, Arun_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# lihat, nadya_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# maaf, Deepa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# maaf, Anastasiia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# maaf, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# maaf, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# maaf, dina_maaf_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# maaf, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# maaf, Ellen_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# maaf, shikha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# maaf, Arun_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# maaf, nadya_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# main, Deepa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# main, Anastasiia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# main, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# main, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# main, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# main, Ellen_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# main, dina_main_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# main, shikha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# main, Arun_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# main, nadya_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# makan, Deepa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# makan, dina_makan_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# makan, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# makan, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# makan, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# makan, Ellen_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# makan, shikha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# makan, Arun_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# makan, nadya_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# marah, louis_0_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# marah, nadya_marah_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# marah, kenzo_13_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# marah, dina_marah_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# marah, Marouf_marah_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# marah, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# marah, Rebecca P_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# marah, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# marah, Deepa_marah_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# marah, thant htoo san_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# marah, marah_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# minum, minum_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# minum, Deepa_minum_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# minum, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# minum, nadya_minum_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# minum, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# minum, thant htoo san_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# minum, Marouf_minum_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# minum, Rebecca_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# minum, kenzo_12_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# minum, louis_12_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# nama, nadya_nama_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# nama, Deepa_nama_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# nama, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# nama, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# nama, nama_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# nama, kenzo_11_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# nama, louis_2_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# nama, thant htoo san_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# nama, Rebecca_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# nama, Marouf_nama_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# orang, louis_3_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# orang, kenzo_14_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# orang, Marouf_orang_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# orang, nadya_orang_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# orang, orang_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# orang, Deepa_orang_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# orang, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# orang, thant htoo san_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# orang, Rebecca_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# panggil, louis_4_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# panggil, Deepa_panggil_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# panggil, Marouf_panggil_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# panggil, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# panggil, panggil_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# panggil, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# panggil, kenzo_15_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# panggil, thant htoo san_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# panggil, Rebecca_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# panggil, nadya_panggil_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# rumah, rumah_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# rumah, Deepa_rumah_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# rumah, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# rumah, Marouf_rumah_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# rumah, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# rumah, thant htoo san_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# rumah, nadya_rumah_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# rumah, Rebecca_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# rumah, louis_5_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# rumah, kenzo_16_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# sedikit, kenzo_17_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# sedikit, sedikit_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# sedikit, nadya_sedikit_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# sedikit, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# sedikit, Deepa_sedikit_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# sedikit, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# sedikit, louis_6_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# sedikit, Marouf_Sedikit_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# sedikit, thant htoo san_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# sedikit, Rebecca_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# selamat, thant_htoo_san_flipped_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# selamat, nadya_selamat_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# selamat, louis_7_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# selamat, selamat_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# selamat, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# selamat, kenzo_18_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# selamat, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# selamat, Marouf_selemat_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# selamat, Deepa_selamat_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# selamat, Rebecca_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# senyum, nadya_senyum_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# senyum, Deepa_senyum_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# senyum, kenzo_20_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# senyum, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# senyum, Marouf_senyum_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# senyum, senyum_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# senyum, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# senyum, louis_8_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# senyum, thant htoo san_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# senyum, Rebecca_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# teman, Deepa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# teman, Anastasiia_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# teman, mahsa_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# teman, kenji_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# teman, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# teman, Ellen_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# teman, shikha_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# teman, Arun_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# teman, nadya_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# tidur, Marouf_tidur_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# tidur, Deepa_tidur_flipped_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# tidur, nadya_tidur_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# tidur, kenzo_19_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# tidur, tidur_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# tidur, 1_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# tidur, Rebecca_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# tidur, thant htoo san (2)_flipped_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0
# tidur, louis_6_flipped_processed.mp4, Frame rate: 30.0, No. of Frames : 30.0, Duration:1.0s, Height 270.0, Width 270.0

# %% [markdown]
# These are preprocessed videos and all of them have the same number of frames, frame rate, duration and image dimensions.

# %%
# Let's take a look at different frames in a single video from the first folder
images = []
for fold in sorted(folds)[:2]:
    files = glob.glob(data_path+fold+"/*.mp4")
    for file in files[:2]:
        # Load the video
        vid = cv2.VideoCapture(file)
        
        # Get the framerate
        fr = vid.get(cv2.CAP_PROP_FPS)

        # Total number of frames
        nframes = vid.get(cv2.CAP_PROP_FRAME_COUNT)

        while True:
            ret, img = vid.read()
            if ret == False:
                break
            else:
                images.append(img)

        # Unload the video
        vid.release()

print(len(images)) 

fig, axs = plt.subplots(4, 4, figsize=(12,10), tight_layout = True)
axs = axs.flatten()
for i in range(len(axs)):
    axs[i].imshow(images[i])
    axs[i].set_title(f"frame:{i}")
    axs[i].axis("off")
plt.show()
# Out:
# 120

# %% [markdown]
# ## Data Preprocessing
# Here we will do a test-train split of the data first. We will try out the model first and then move on the data augmentation part. For that we need to collect the filepath of each video file and the associated labeling with it. There are in total 30 output classes which can be labelled from 0 to 29.
#
# ### Data Splitting

# %%
# data frame containing list of files and labels
df.head(10)
# Out:
#                                                 X_path   Y
# 218  ../data/data_processed_v1/nama/Rebecca_process...  21
# 107  ../data/data_processed_v1/jalan/shikha_process...  10
# 90   ../data/data_processed_v1/ibu/Viorelia_process...   9
# 201  ../data/data_processed_v1/minum/Deepa_minum_pr...  20
# 129  ../data/data_processed_v1/kertas/nadya_process...  12
# 181  ../data/data_processed_v1/makan/dina_makan_pro...  18
# 258  ../data/data_processed_v1/sedikit/Rebecca_proc...  25
# 33   ../data/data_processed_v1/buka/Bhavitha_Bojja_...   3
# 137  ../data/data_processed_v1/kucing/shikha_proces...  13
# 120  ../data/data_processed_v1/kertas/Deepa_process...  12

# %%
from sklearn.model_selection import train_test_split

# stratisfied splitting the data into 70% train and 30 % test to ensure that the test data contains 
# more or less equal distributions of different classes
X_train_path, X_test_path, Y_train, Y_test = train_test_split(df['X_path'], df['Y'], test_size=0.2, random_state=42, stratify = df['Y'])

# checking the number of samples in each category of the test data
Y_test.value_counts().sort_values()
#X_train_path.head(5)
# Out:
# Y
# 13    2
# 14    2
# 10    2
# 9     2
# 19    2
# 7     2
# 23    2
# 26    2
# 24    2
# 27    2
# 22    2
# 29    2
# 20    2
# 4     2
# 28    2
# 15    2
# 12    2
# 11    2
# 5     2
# 8     2
# 17    2
# 1     2
# 3     2
# 16    2
# 18    2
# 25    2
# 0     2
# 6     2
# 2     2
# 21    2
# Name: count, dtype: int64

# %% [markdown]
# ### Data extraction from the video files

# %%
def load_data(df):
    """
    Returns the array with loaded images from
    videos
    args:
    df : dataframe containing the filepaths
    """
    samp = df.shape[0]
    #print(samp)
    data = np.zeros((samp, 30, 270, 270, 3), dtype = np.float32) # Each video has 30 frames and each frame has 224 pixels height, width and 3 channels
    for i in range(samp):
        filename = df.iloc[i]
        
        # Load the video
        vid = cv2.VideoCapture(filename)
        
        # Total number of frames
        nframes = int(vid.get(cv2.CAP_PROP_FRAME_COUNT))

        for f in range(nframes):
            
            ret, img = vid.read()
            if ret == False:
                break
            else:
                data[i,f,:,:,:] = img/255

        # Unload the video
        vid.release()

    return data

# %%
# Get the train data and test data

X_train = load_data(X_train_path)
X_test = load_data(X_test_path)

print(f" X train shape : {X_train.shape}")
print(f"X test shape : {X_test.shape}")
# Out:
#  X train shape : (237, 30, 270, 270, 3)
# X test shape : (60, 30, 270, 270, 3)

# %%
# Let's plot a random video file (eg: 30 th file) and check the data frames
fig, axs = plt.subplots(4, 4, figsize=(12,10), tight_layout = True)
axs = axs.flatten()
for i in range(len(axs)):
    axs[i].imshow(X_train[30, i, :, :, :])
    axs[i].set_title(f"frame:{i}")
    axs[i].axis("off")
plt.show()

# %% [markdown]
# ## Modeling of the data
# We will start with a simple CNN-LSTM model and see how it performs. Depending on the metrics, we can carry out video augmentation and other models. Let's build the model using keras and tensorflow.
#
# In the case of a CNN-LSTM model, the CNN will extract the features from each frame of the image and they are fed to the LSTM model for modeling the temporal variations in the video. The **TimeDistributed** wrapper in Keras can be used to apply the same convolutionsl operations to different time frames and combine the results after that. Let's build the model now.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D, Dropout, Input, TimeDistributed, LSTM, GlobalAveragePooling2D

def create_CNN_LSTM(input_shape, nclass):

    """
    Function returns the model output
    Args:
    input shape: shape of the input train/test data (excluding the batch size)
    nclass: number of output classes
    """
    model = Sequential()

    # CNN part
    model.add(Input(shape=input_shape))
    model.add(TimeDistributed(Conv2D(filters=32, kernel_size=3, strides=(2,2), activation='relu', padding='valid', name = 'conv1')))
    model.add(TimeDistributed(MaxPool2D(pool_size=(2, 2), strides=(2,2), name = 'pool1')))
    model.add(TimeDistributed(Conv2D(filters=64, kernel_size=3, strides=(2,2), activation='relu', padding='valid', name = 'conv2')))
    model.add(TimeDistributed(MaxPool2D(pool_size=(2, 2), strides=(2,2), name = 'pool2')))
    model.add(TimeDistributed(Conv2D(filters=128, kernel_size=3, strides=(2,2), activation='relu', padding='valid', name = 'conv3')))
    model.add(TimeDistributed(MaxPool2D(pool_size=(4, 4), strides=(4,4), name = 'pool3')))

    # flattening
    model.add(TimeDistributed(Flatten()))
              
    # LSTM part
    model.add(LSTM(64))
              
    # Drop out regularization
    model.add(Dropout(0.2))
              
    # fully connected layers
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))

    # Final output layer, softmax regression
    model.add(Dense(nclass, activation='softmax'))

    return model

# %%
nclass = len(np.unique(Y_train))
input_shape = X_train.shape[1:] 

print(f"Number of classes : {nclass}")
# Out:
# Number of classes : 30
# 2025-01-14 09:59:13.317274: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 30, 134, 134, 32)  896
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 30, 67, 67, 32)   0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 30, 33, 33, 64)   18496
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 30, 16, 16, 64)   0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 30, 7, 7, 128)    73856
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 30, 1, 1, 128)    0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 30, 128)          0
#  tributed)
#
#  lstm (LSTM)                 (None, 64)                49408
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 128)               8320
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 30)                1950
#
# =================================================================
# Total params: 161,182
# Trainable params: 161,182
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model summary
cnn_lstm.summary()

# Creating the model
cnn_lstm = create_CNN_LSTM(input_shape, nclass)

# %%
import tensorflow as tf

def keras_model_memory_usage_in_bytes(model, batch_size: int):
    """
    Return the estimated memory usage of a given Keras model in bytes.
    This includes the model weights and layers, but excludes the dataset.

    The model shapes are multipled by the batch size, but the weights are not.

    Args:
        model: A Keras model.
        batch_size: The batch size you intend to run the model with. If you
            have already specified the batch size in the model itself, then
            pass `1` as the argument here.
    Returns:
        An estimate of the Keras model's memory usage in bytes.

    """
    default_dtype = tf.keras.backend.floatx()
    shapes_mem_count = 0
    internal_model_mem_count = 0
    for layer in model.layers:
        if isinstance(layer, tf.keras.Model):
            internal_model_mem_count += keras_model_memory_usage_in_bytes(
                layer, batch_size=batch_size
            )
        single_layer_mem = tf.as_dtype(layer.dtype or default_dtype).size
        out_shape = layer.output_shape
        if isinstance(out_shape, list):
            out_shape = out_shape[0]
        for s in out_shape:
            if s is None:
                continue
            single_layer_mem *= s
        shapes_mem_count += single_layer_mem

    trainable_count = sum(
        [tf.keras.backend.count_params(p) for p in model.trainable_weights]
    )
    non_trainable_count = sum(
        [tf.keras.backend.count_params(p) for p in model.non_trainable_weights]
    )

    total_memory = (
        batch_size * shapes_mem_count
        + internal_model_mem_count
        + trainable_count
        + non_trainable_count
    )
    return total_memory

#print(keras_model_memory_usage_in_bytes(cnn_lstm, 32)/1e+9)

# %%
# compile and train the model
cnn_lstm.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
# If the y labels are intigers use sparse categorical entropy loss function, if y labels are one hot encoded then utilize the categorical
# cross entropy

# let's set the test data as the validation data as of now since we have limited data for training.
hist_cnn_lstm = cnn_lstm.fit(X_train, Y_train, epochs=10, batch_size=32, validation_data = (X_test, Y_test))
# Out:
# Epoch 1/10
# 8/8 [==============================] - 47s 5s/step - loss: 3.4062 - accuracy: 0.0380 - val_loss: 3.4032 - val_accuracy: 0.0333
# Epoch 2/10
# 8/8 [==============================] - 42s 5s/step - loss: 3.4036 - accuracy: 0.0253 - val_loss: 3.4024 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 8/8 [==============================] - 43s 5s/step - loss: 3.4038 - accuracy: 0.0422 - val_loss: 3.4021 - val_accuracy: 0.0333
# Epoch 4/10
# 8/8 [==============================] - 42s 5s/step - loss: 3.4016 - accuracy: 0.0464 - val_loss: 3.4026 - val_accuracy: 0.0333
# Epoch 5/10
# 8/8 [==============================] - 41s 5s/step - loss: 3.4026 - accuracy: 0.0422 - val_loss: 3.4022 - val_accuracy: 0.0333
# Epoch 6/10
# 8/8 [==============================] - 41s 5s/step - loss: 3.4018 - accuracy: 0.0338 - val_loss: 3.4037 - val_accuracy: 0.0333
# Epoch 7/10
# 8/8 [==============================] - 42s 5s/step - loss: 3.4013 - accuracy: 0.0169 - val_loss: 3.4053 - val_accuracy: 0.0333
# Epoch 8/10
# 8/8 [==============================] - 42s 5s/step - loss: 3.4006 - accuracy: 0.0295 - val_loss: 3.4038 - val_accuracy: 0.0333
# Epoch 9/10
# 8/8 [==============================] - 38s 5s/step - loss: 3.4014 - accuracy: 0.0127 - val_loss: 3.4025 - val_accuracy: 0.0333
# Epoch 10/10
# 8/8 [==============================] - 30s 4s/step - loss: 3.4001 - accuracy: 0.0338 - val_loss: 3.4027 - val_accuracy: 0.0333

# %%
# The history.history["loss"] entry is a dictionary with as many values as epochs that the
# model was trained on. 
df_loss_acc = pd.DataFrame(hist_cnn_lstm.history)

# losses data frame
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)

# accuracy data frame
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)

# plotting the loss and accuracy
df_loss.plot(title='Model loss',figsize=(8,6)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(8,6)).set(xlabel='Epoch',ylabel='Accuracy')

# %% [markdown]
# ### Resnet-LSTM Model
# Since the basic model is not doing a good job in learing from the data. Let's replace the CNN with a ResNet model. The Resnet model is very good in detecting complicated patters from the images.

# %%
from tensorflow.keras.applications import ResNet50

def call_resnet(input_shape):
    
    # Calling the Resnet model
    res_model = ResNet50(
    include_top=False, # remove the top layer or the classification layer.
    weights="imagenet", # utilize imagenet weights
    input_tensor=None,
    input_shape=input_shape[1:], # time steps axis not needed here
    pooling=None)  # no pooling mentioned

    #print a summary of the base model
    #res_model.summary()

    nb_layers = len(res_model.layers)
    print(f"No. of Resnet model layers: {nb_layers}")

    # Freeze the base model as we wan to use the pretrained weights
    res_model.trainable = False

    return res_model

def create_ResNet_LSTM(input_shape, nclass):

    """
    Function returns the model output
    Args:
    input shape: shape of the input train/test data (excluding the batch size)
    nclass: number of output classes
    """
    # start the model
    model = Sequential()

    # defining the input layer
    model.add(Input(shape=input_shape))

    # resnet layer for feature extraction
    model.add(TimeDistributed(call_resnet(input_shape))) # calling the resnet function here

    # adding a 2D global average to reduce the size and summarize the info in each channel
    model.add(TimeDistributed(GlobalAveragePooling2D()))
    
    # flattening  not needed anymore with the global averaging
    #model.add(TimeDistributed(Flatten()))
              
    # LSTM part
    model.add(LSTM(64))
              
    # Drop out regularization
    model.add(Dropout(0.2))
              
    # fully connected layers
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))

    # Final output layer, softmax regression
    model.add(Dense(nclass, activation='softmax'))

    return model

# %%
# Create the model
res_lstm = create_ResNet_LSTM(input_shape, nclass)
# Out:
# No. of Resnet model layers: 175

# %%
#Summary of the model
res_lstm.summary()

print(f" Size of the Model in GB : {keras_model_memory_usage_in_bytes(res_lstm, 32)/1e+9}")
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_26 (TimeDi  (None, 30, 9, 9, 2048)   23587712
#  stributed)
#
#  time_distributed_27 (TimeDi  (None, 30, 2048)         0
#  stributed)
#
#  lstm_10 (LSTM)              (None, 64)                540928
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_30 (Dense)            (None, 128)               8320
#
#  dense_31 (Dense)            (None, 64)                8256
#
#  dense_32 (Dense)            (None, 30)                1950
#
# =================================================================
# Total params: 24,147,166
# Trainable params: 559,454
# Non-trainable params: 23,587,712
# _________________________________________________________________
#  Size of the Model in GB : 0.669066206

# %%
# compile and train the model
res_lstm.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
# If the y labels are intigers use sparse categorical entropy loss function, if y labels are one hot encoded then utilize the categorical
# cross entropy

# let's set the test data as the validation data as of now since we have limited data for training.
hist_res_lstm = res_lstm.fit(X_train, Y_train, epochs=10, batch_size=32, validation_data = (X_test, Y_test))
# Out:
# Epoch 1/10
# 8/8 [==============================] - 802s 101s/step - loss: 3.4472 - accuracy: 0.0253 - val_loss: 3.4072 - val_accuracy: 0.0333
# Epoch 2/10
# 8/8 [==============================] - 796s 101s/step - loss: 3.4138 - accuracy: 0.0506 - val_loss: 3.4052 - val_accuracy: 0.0333
# Epoch 3/10
# 8/8 [==============================] - 784s 100s/step - loss: 3.4068 - accuracy: 0.0295 - val_loss: 3.4036 - val_accuracy: 0.0333
# Epoch 4/10
# 1/8 [==>...........................] - ETA: 9:58 - loss: 3.4116 - accuracy: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[107], line 7
#       2 res_lstm.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
#       3 # If the y labels are intigers use sparse categorical entropy loss function, if y labels are one hot encoded then utilize the categorical
#       4 # cross entropy
#       5
#       6 # let's set the test data as the validation data as of now since we have limited data for training.
# ----> 7 hist_res_lstm = res_lstm.fit(X_train, Y_train, epochs=10, batch_size=32, validation_data = (X_test, Y_test))
#
# File ~/opt/anaconda3/envs/ds/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/opt/anaconda3/envs/ds/lib/python3.9/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/opt/anaconda3/envs/ds/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/opt/anaconda3/envs/ds/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/opt/anaconda3/envs/ds/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/opt/anaconda3/envs/ds/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/opt/anaconda3/envs/ds/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/opt/anaconda3/envs/ds/lib/python3.9/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/opt/anaconda3/envs/ds/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Conclusion
#
# The simple CNN-LSTM model is not learning well as we can see from the training history. The issues causing this needs to be figured out.
